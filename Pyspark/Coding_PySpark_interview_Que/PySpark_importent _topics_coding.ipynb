# %% [markdown]
# You already have experience with **ADF + Databricks + PySpark + SQL**, so interviewers are likely to give you practical ETL-style problems rather than only Python puzzles.
#
# ---
#
# 🔥 **Complete PySpark Coding Practice Set — 3+ Years**
#
# ---
#
# 🟢 **Level 1 — Basic DataFrame coding**
#
# - Read CSV, JSON and Parquet files using PySpark.
# - Read a CSV using an explicit schema.
# - Select specific columns from a DataFrame.
# - Rename multiple columns.
# - Add a new column using `withColumn()`.
# - Apply multiple conditions using `when()` / `otherwise()`.
# - Filter records based on multiple conditions.
# - Convert a string column to date/timestamp.
# - Handle NULL values using `fillna()`, `dropna()` and `when()`.
# - Remove duplicate records.
# - Count total rows and distinct values.
# - Find distinct customers.
# - Sort a DataFrame by multiple columns.
# - Convert a column to uppercase/lowercase.
# - Extract year, month and day from a date.
# - Concatenate multiple columns.
# - Split a string column.
# - Extract data using regular expressions.
# - Create a column based on multiple business conditions.
# - Rename columns dynamically.
#
# ---
#
# 🟡 **Level 2 — Aggregation & GroupBy**
#
# - Find total transaction amount per customer.
# - Find customers whose total transaction amount is greater than 1000.
# - Find average salary per department.
# - Find maximum and minimum salary per department.
# - Find the number of employees in each department.
# - Find departments having more than 10 employees.
# - Find the highest salary in each department.
# - Find the second-highest salary in each department.
# - Find duplicate customers using `groupBy()`.
# - Calculate multiple aggregations in a single `groupBy()`.
# - Calculate daily/monthly transaction totals.
# - Find the customer with the highest total transaction amount.
# - Find the department with the highest average salary.
#
# ---
#
# 🔴 **Level 3 — Window Functions ⭐⭐⭐⭐⭐**
#
# This is extremely important for interviews.
#
# - Find the latest transaction for each customer.
# - Find the first transaction for each customer.
# - Find the second-highest salary in each department.
# - Find top 3 salaries in each department.
# - Find top N transactions per customer.
# - Use `row_number()` to remove duplicates while keeping the latest record.
# - Difference/use case of `row_number()`, `rank()` and `dense_rank()`.
# - Calculate running/cumulative transaction amount.
# - Calculate customer-wise running balance.
# - Find previous transaction using `lag()`.
# - Find next transaction using `lead()`.
# - Calculate difference between current and previous transaction.
# - Find customers whose current transaction is greater than their previous transaction.
# - Find the first and last transaction for every customer.
# - Find consecutive transactions/dates.
#
# ---
#
# 🔵 **Level 4 — Joins ⭐⭐⭐⭐⭐**
#
# - Perform inner join between two DataFrames.
# - Perform left join between two DataFrames.
# - Perform full outer join.
# - Find records existing in A but not B.
# - Find records existing in both A and B.
# - Join DataFrames having duplicate column names.
# - Join DataFrames using multiple columns.
# - Join DataFrames when column names are different.
# - Perform a broadcast join.
# - Explain/implement a solution for a large fact table + small dimension table.
# - Handle duplicate records generated after a join.
# - Find unmatched records after a left join.
# - Join three or more DataFrames.
#
# ---
#
# 🟣 **Level 5 — Complex Transformations**
#
# - Explode an array column.
#
#   Example:
#
#   | customer_id | products  |
#   |-------------|-----------|
#   | 101         | [A,B,C]   |
#
#   Convert it into:
#
#   | customer_id | product |
#   |-------------|---------|
#   | 101         | A       |
#   | 101         | B       |
#   | 101         | C       |
#
# - Explode nested JSON data.
# - Flatten a nested DataFrame.
# - Work with struct columns.
# - Work with arrays and maps.
# - Pivot data.
# - Unpivot data.
# - Convert rows into columns.
# - Convert columns into rows.
# - Use `collect_list()`.
# - Use `collect_set()`.
# - Create comma-separated values using `concat_ws()`.
# - Parse nested JSON.
#
# ---
#
# 🟠 **Level 6 — Real ETL Coding ⭐⭐⭐⭐⭐**
#
# These are particularly important for Azure/Databricks interviews.
#
# - Read incremental data based on `last_modified_date`.
# - Process only records modified after the last successful run.
# - Implement incremental load using PySpark.
# - Identify new vs existing records.
# - Implement SCD Type 1 logic.
# - Implement SCD Type 2 logic.
# - Implement SCD Type 2 using Delta Lake/MERGE.
# - Remove duplicates from incoming data while keeping the latest record.
# - Handle late-arriving records.
# - Handle NULL/default values during ingestion.
# - Compare source and target counts.
# - Find records missing from the target.
# - Implement data-quality checks.
# - Create reject/error records for invalid data.
# - Process multiple files from ADLS.
# - Write transformed data to Delta.
#
# ---
#
# 🟤 **Level 7 — Delta Lake / Databricks Coding ⭐⭐⭐⭐⭐**
#
# For a Databricks interview, don't skip this section.
#
# - Read a Delta table.
# - Write a DataFrame as Delta.
# - Append data to a Delta table.
# - Overwrite a Delta table.
# - Perform Delta MERGE.
# - Implement SCD Type 1 using MERGE.
# - Implement SCD Type 2 using MERGE.
# - Delete records from a Delta table.
# - Update records in a Delta table.
# - Read Delta table history.
# - Perform time travel.
# - Handle schema evolution.
# - Optimize a Delta table.
# - Explain/use OPTIMIZE.
# - Explain/use VACUUM.
# - Partition a Delta table.
# - Explain why you shouldn't blindly partition by high-cardinality columns.
#
# ---
#
# ⚡ **Level 8 — Performance Coding ⭐⭐⭐⭐⭐**
#
# This is where a 3+ year candidate can be differentiated from a fresher.
#
# - Optimize a slow join.
# - Use `broadcast()` for a small dimension table.
# - Handle a skewed join.
# - Use salting to solve data skew.
# - Compare `repartition()` and `coalesce()` with examples.
# - Repartition data before writing.
# - Reduce the number of output files.
# - Handle the small file problem.
# - Use `cache()`/`persist()` appropriately.
# - Avoid unnecessary `collect()`.
# - Explain why `groupBy()` can cause a shuffle.
# - Optimize unnecessary shuffles.
# - Use column pruning.
# - Use filter/predicate pushdown.
# - Optimize a DataFrame containing many transformations.
# - Identify why a Spark job is slow from the Spark UI.
#
# ---
#
# 🟢 **Level 9 — SQL + PySpark Combined ⭐⭐⭐⭐⭐**
#
# Interviewers frequently switch between SQL and PySpark.
#
# - Find the second-highest salary.
# - Find the nth-highest salary.
# - Find duplicate records.
# - Delete duplicates while keeping the latest record.
# - Find latest transaction per customer.
# - Find customers with no transactions.
# - Find customers who transacted in consecutive months.
# - Find month-over-month revenue.
# - Find running total.
# - Find top 3 customers per month.
# - Find employees earning more than department average.
# - Find gaps in dates.
# - Find consecutive records.
# - Implement SCD Type 2 in SQL/PySpark.
#
# ---
#
# 🔥 **Level 10 — Scenario-Based Coding**
#
# These are the ones I'd definitely practice before your interview.
#
# - You receive 100 CSV files daily in ADLS. Write PySpark logic to process them.
# - The same file may arrive twice. How do you prevent duplicate processing?
# - A file contains 10 million records, but only 50,000 are new. How do you process incrementally?
# - Source has duplicate customer records. Keep only the latest record.
# - Source schema changes unexpectedly. How will you handle it?
# - One customer has millions of transactions, causing data skew. How do you solve it?
# - Your join between a 1 TB fact table and a 20 MB dimension table is slow. What will you do?
# - Your Databricks job creates thousands of small files. How will you fix it?
# - Your Spark job is running out of memory. How do you troubleshoot it?
# - Your job takes 2 hours today but normally takes 20 minutes. How do you investigate?
# - Source and target counts don't match. Write logic to identify the problematic records.
# - Implement an incremental pipeline using a watermark column.
# - Implement SCD Type 2 for a customer dimension.
#
# ---
#
# 🎯 **If you have limited time**
#
# Don't try to solve all 150 immediately.
#
# For your Azure + Databricks + PySpark 3+ year interview, I'd make these **30 mandatory coding questions**:
#
# - DataFrame
# - Explicit schema
# - Filtering
# - NULL handling
# - Duplicate removal
# - Date transformations
# - Aggregation
# - GroupBy + aggregation
# - Having condition
# - Highest/second-highest salary
# - Monthly aggregation
# - Window
# - Latest transaction per customer
# - Top 3 per group
# - row_number
# - rank
# - dense_rank
# - lag
# - lead
# - Running total
# - Joins
# - Inner join
# - Left join
# - Anti join
# - Broadcast join
# - Join with duplicate columns
# - Complex
# - Explode
# - Flatten JSON
# - Pivot/unpivot
# - ETL
# - Incremental load
# - Deduplication + latest record
# - SCD Type 1
# - SCD Type 2
# - Delta MERGE
#
# Performance questions should then be practiced separately: repartition/coalesce, shuffle, skew, broadcast, caching, small files, partition pruning and predicate pushdown.
#
# If you can actually code these 30 without looking at the answer, you'll have covered the large majority of the PySpark coding patterns that are likely to appear in a 3–4 year Azure/Databricks Data Engineer interview.
